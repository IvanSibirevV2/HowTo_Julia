# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ветвления и Циклы

# %%
b=1;(b==0) ? true : false
# Out:
# false

# %%
b=0;(b==0)? 0 : (b==1) ? a : "$b" * "*(" * a * ")"
# Out:
# 0

# %%
b=readline()
if(b==0)
    0|>println
elseif (b==1)
    1|>println
else
    "\"$b\""|>println
end;
# Out:
# stdin> 0
# "0"
