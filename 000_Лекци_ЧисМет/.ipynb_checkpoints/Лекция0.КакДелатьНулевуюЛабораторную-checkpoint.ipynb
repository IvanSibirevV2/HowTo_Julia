# %% [markdown]
# # Нулевая лабораторная работа. Установить и запустить
#
# <a href="https://julialang.org/downloads/">Установить язык Julia</a>, так как он посильнее Pyton будет.<br/>
# <a href="https://docs.julialang.org/en/v1/">Заглянуть в документацию языка Julia</a>.<br/>
# <a href="https://github.com/IvanSibirevV2/HowTo_Julia.git">Заглянуть в гит репозиторий примеров</a>, он ещё разрастется.<br/>
# Создать $*$.jl файл и запустить его

# %%
#$*$.jl
println("HelloWorld!")
"Hello, World!"|>println
println(VERSION)
# Out:
# HelloWorld!
# Hello, World!
# 1.5.3

# %% [markdown]
# - 1)![image.png](attachment:image.png)
# - 2)![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
# - 3) Выбрать как программу открытия по умолчанию "C:\Users\SibNout2020\AppData\Local\Programs\Julia 1.5.3\bin\julia.exe"
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <a href="https://www.anaconda.com/products/individual">Установить менеджер пакетов Pyton Anaconda</a>.<br/>
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Накатить пакет IJulia через консоль
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# Нажмите пробел. Можно понять что пакет установился по появившимся пустым строкам...

# %% [markdown]
# Обратите внимание, эта система позволяет писать документы, добавлять картинки и формулы. Чем мы и займемся.
# Выберете Ваш вариант формулы и оформите его в Блокноте через латех. Если не получитая тогда просто запрограммируйте.
# Подробное описание как работать с латехом можно найти в следующей лекции. Не забудте сделать титульник. Вот подробное описание MarkdownHTML
# https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd
# ![image.png](attachment:image.png)

# %% [markdown]
# # Вариант 1

# %% [markdown]
# Вариант 1.$$\begin{aligned}\frac{b+\sqrt{b^2+4ac}}{2a}-a^3c+b^{-2}\end{aligned}$$

# %%
println("Вариант 1");
a=1;
b=2;
c=3;
@show (b+sqrt(b^2+4*a*c))/(2*a)-c*a^3+b^(-2)
y=(b+sqrt(b^2+4*a*c))/(2*a)-c*a^3+b^(-2)
println("y=",y);
# Out:
# Вариант 1
# ((b + sqrt(b ^ 2 + 4 * a * c)) / (2a) - c * a ^ 3) + b ^ -2 = 0.25
# y=0.25

# %%
println("Вариант 7");
x=4;
y=7
z=log(10,(y-sqrt(abs(x)))*(x-y/(x+(x^2)/4)))
println("z=",z);
z=log(10,(y-(x|>abs|>sqrt))*(x-y/(x+(x^2)/4)))
println("z=",z);
# Out:
# Вариант 7
# z=1.1938200260161127
# z=1.1938200260161127

# %%
println("Вариант 8");
x=0.4
y=1
(1-tan(x))^(acot(x))+cos(x+y)|>println;
# Out:
# Вариант 8
# 0.6898616076024452

# %%
println("Base.MathConstants.e=",Base.MathConstants.e+0);
println("Base.MathConstants.pi=",Base.MathConstants.pi+0);
# Out:
# Base.MathConstants.e=2.718281828459045
# Base.MathConstants.pi=3.141592653589793

# %%
x=5
y=log(Base.MathConstants.e,cos(x))/log(Base.MathConstants.e,1+x^2)
println("y=",y);
# Out:
# y=-0.38672004402721605
