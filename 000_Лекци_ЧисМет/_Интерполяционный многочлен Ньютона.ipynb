# %% [markdown]
# # Интерполяционный многочлен Ньютона
#
# Шаг первый, дана таблица
# ![image.png](attachment:image.png)
# По ней строим таблицу
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Шаг второй. Выбираем одну из формул, что проще будет для нас.
# ![image.png](attachment:image.png)
# - для значений близких к x1
# ![image-2.png](attachment:image-2.png)
# - для значений близких к xn

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
