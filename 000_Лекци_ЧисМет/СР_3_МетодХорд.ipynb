# %% [markdown]
# МетодНьютонаДеления

# %% [markdown]
# Шаг первый. Графически локализовать корни.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
using Plots;
using Latexify,LaTeXStrings,SymEngine;
#Пример демонстрирует что у каждого графика можно сделать свой диапазон отображения
_xlim=(-2.5,4)
_ylim=(-25, 25)
plot(title = "")
plot!(x->(2*x^3-3*x^2-12x^1-5), label = L"2*x^3-3*x^2-12x^1-5",xlim=_xlim,ylim=_ylim)
plot!(x->0, xlim=_xlim, ylim=_ylim)
plot!(xlabel = "OX")
ylabel!("OY")
plot!(size=(400,200))

# %% [markdown]
# Методом половинного деления уточникть корни до заданной точности

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
function Sign(x::Core.Real);return Base.cmp(x,0);end;
function MetoXord(
    _xlastlast::Core.Real
    ,_xlast::Core.Real
    ,F=(x^3+3*x^2-24*x^1-10)
    ,e::Core.Real=0.01
)
    i=0;
    _flag =false
    while ((!_flag)&&(i<10));
        i=i+1;
        _xnext=_xlast-(_xlast-_xlastlast)*F(_xlast)/(F(_xlast)-F(_xlastlast));
        _flag=(Base.abs(_xlast-_xnext)<e);
        "$_xnext $_flag"|>println;
        _xlast=_xlastlast;
        _xlast=_xnext;
    end;
end;
MetoXord(-3,-2,x->(x^3+3*x^2-24*x^1-10),0.000001);
# Out:
# 0.10000000000000009 false
# -0.4155898290954564 false
# -0.39794106816910557 false
# -0.3995080689800367 false
# -0.39937176318871226 false
# -0.3993836416076997 false
# -0.3993826066239922 false
# -0.39938269680486616 true
