# %% [markdown]
# МетодНьютонаДеления

# %% [markdown]
# Шаг первый. Графически локализовать корни.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
using Plots;
using Latexify,LaTeXStrings,SymEngine;
#Пример демонстрирует что у каждого графика можно сделать свой диапазон отображения
_xlim=(-2.5,4)
_ylim=(-25, 25)
plot(title = "")
plot!(x->(2*x^3-3*x^2-12x^1-5), label = L"2*x^3-3*x^2-12x^1-5",xlim=_xlim,ylim=_ylim)
plot!(x->0, xlim=_xlim, ylim=_ylim)
plot!(xlabel = "OX")
ylabel!("OY")
plot!(size=(400,200))

# %% [markdown]
# Методом половинного деления уточникть корни до заданной точности

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
function Sign(x::Core.Real);return Base.cmp(x,0);end;
function MetoDelenia(
    _xlast::Core.Real
    ,F=(x^3+3*x^2-24*x^1-10)
    ,F_=(3x^2+3*2*x-24)
    ,e::Core.Real=0.01
)
    i=0;
    _flag =false
    while ((!_flag)&&(i<10));
        i=i+1;
        _xnext=_xlast-F(_xlast)/F_(_xlast)
        
        _flag=Base.abs(_xlast-_xnext)<e
        "$_xnext $_flag"|>println;
        _xlast=_xnext;
    end;
end;
MetoDelenia(1,x->(x^3+3*x^2-24*x^1-10),x->(3x^2+3*2*x-24),0.000001);
""|>println;
MetoDelenia(4,x->(x^3+3*x^2-24*x^1-10),x->(3x^2+3*2*x-24),0.000001)
""|>println;
MetoDelenia(-2,x->(x^3+3*x^2-24*x^1-10),x->(3x^2+3*2*x-24),0.000001)
# Out:
# -1.0 false
# -0.40740740740740744 false
# -0.39938712172389146 false
# -0.3993826895783284 false
# -0.39938268957696277 true
#
# 3.875 false
# 3.869753086419753 false
# 3.869743968804955 false
# 3.8697439687774433 true
#
# -0.25 false
# -0.4012345679012346 false
# -0.3993829274476852 false
# -0.39938268957696665 true
