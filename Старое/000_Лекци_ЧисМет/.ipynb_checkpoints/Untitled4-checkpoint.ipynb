# %% [markdown]
# # Численное интегрирование
# Положим есть функция $f(x)$, и есть некоторая функция $F(x)$. <br/>
# Функция $F(x)$ называется первообразной функцией $f(x)$, если $F^\prime(x)=f(x)$<br/>
# П.1. Постановка задачи.
# Многие задачи физики, техники, экономики требуют нахождения определенного интеграла.
# Простым способом вычисления определенного интеграла является применение формулы Ньютона – Лейбница:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Формула прямоугольников
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Формула трапеций
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# А теперь поиск площади по формуле для трапеций
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Формула Симпсона
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Метод Рунге
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) - сумма подинтегралов с шагом в два раза меньшим чем H
